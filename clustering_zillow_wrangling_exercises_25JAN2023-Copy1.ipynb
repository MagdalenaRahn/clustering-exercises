# %% [markdown]
# ## CLUSTERING : DATA WRANGLING WITH ZILLOW & THE MALL
#
# 25 January 2023

# %%
# imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import prepare
from env import sql_connexion

from sklearn.preprocessing import MinMaxScaler

# %%
# # getting sql_connexion from acquire.py

# url = sql_connexion('zillow')

# %%
# # defining the query

# query = '''
#         select *
#         from properties_2017
#         join predictions_2017 using (parcelid)
#         join propertylandusetype USING(propertylandusetypeid)
#         '''

# %%
# putting it together 

df = pd.read_csv('zillow.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 77579 entries, 0 to 77578
# Data columns (total 69 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   parcelid                      77579 non-null  int64
#  1   typeconstructiontypeid        223 non-null    float64
#  2   storytypeid                   50 non-null     float64
#  3   propertylandusetypeid         77579 non-null  float64
#  4   heatingorsystemtypeid         49571 non-null  float64
#  5   buildingclasstypeid           15 non-null     float64
#  6   architecturalstyletypeid      207 non-null    float64
#  7   airconditioningtypeid         25007 non-null  float64
#  8   id                            77579 non-null  int64
#  9   basementsqft                  50 non-null     float64
#  10  bathroomcnt                   77579 non-null  float64
#  11  bedroomcnt                    77579 non-null  float64
#  12  buildingqualitytypeid         49809 non-null  float64
#  13  calculatedbathnbr             76963 non-null  float64
#  14  decktypeid                    614 non-null    float64
#  15  finishedfloor1squarefeet      6037 non-null   float64
#  16  calculatedfinishedsquarefeet  77378 non-null  float64
#  17  finishedsquarefeet12          73923 non-null  float64
#  18  finishedsquarefeet13          42 non-null     float64
#  19  finishedsquarefeet15          3027 non-null   float64
#  20  finishedsquarefeet50          6037 non-null   float64
#  21  finishedsquarefeet6           386 non-null    float64
#  22  fips                          77579 non-null  float64
#  23  fireplacecnt                  8289 non-null   float64
#  24  fullbathcnt                   76963 non-null  float64
#  25  garagecarcnt                  25520 non-null  float64
#  26  garagetotalsqft               25520 non-null  float64
#  27  hashottuborspa                1539 non-null   float64
#  28  latitude                      77579 non-null  float64
#  29  longitude                     77579 non-null  float64
#  30  lotsizesquarefeet             69321 non-null  float64
#  31  poolcnt                       16174 non-null  float64
#  32  poolsizesum                   869 non-null    float64
#  33  pooltypeid10                  465 non-null    float64
#  34  pooltypeid2                   1074 non-null   float64
#  35  pooltypeid7                   15079 non-null  float64
#  36  propertycountylandusecode     77579 non-null  object
#  37  propertyzoningdesc            50476 non-null  object
#  38  rawcensustractandblock        77579 non-null  float64
#  39  regionidcity                  76107 non-null  float64
#  40  regionidcounty                77579 non-null  float64
#  41  regionidneighborhood          30974 non-null  float64
#  42  regionidzip                   77529 non-null  float64
#  43  roomcnt                       77579 non-null  float64
#  44  threequarterbathnbr           10106 non-null  float64
#  45  unitcnt                       50703 non-null  float64
#  46  yardbuildingsqft17            2393 non-null   float64
#  47  yardbuildingsqft26            70 non-null     float64
#  48  yearbuilt                     77309 non-null  float64
#  49  numberofstories               17599 non-null  float64
#  50  fireplaceflag                 172 non-null    float64
#  51  structuretaxvaluedollarcnt    77464 non-null  float64
#  52  taxvaluedollarcnt             77578 non-null  float64
#  53  assessmentyear                77579 non-null  float64
#  54  landtaxvaluedollarcnt         77577 non-null  float64
#  55  taxamount                     77574 non-null  float64
#  56  taxdelinquencyflag            2900 non-null   object
#  57  taxdelinquencyyear            2900 non-null   float64
#  58  censustractandblock           77332 non-null  float64
#  59  id.1                          77579 non-null  int64
#  60  logerror                      77579 non-null  float64
#  61  transactiondate               77579 non-null  object
#  62  airconditioningdesc           25007 non-null  object
#  63  architecturalstyledesc        207 non-null    object
#  64  buildingclassdesc             15 non-null     object
#  65  heatingorsystemdesc           49571 non-null  object
#  66  propertylandusedesc           77579 non-null  object
#  67  storydesc                     50 non-null     object
#  68  typeconstructiondesc          223 non-null    object
# dtypes: float64(55), int64(3), object(11)
# memory usage: 40.8+ MB
# /var/folders/v1/7y2hc6q17wl2rjlpg8h9g78h0000gn/T/ipykernel_2123/3709608481.py:3: DtypeWarning: Columns (64) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('zillow.csv')

# %%
df.head()
# Out:
#    parcelid  typeconstructiontypeid  storytypeid  propertylandusetypeid  \
# 0  14297519                     NaN          NaN                  261.0
# 1  17052889                     NaN          NaN                  261.0
# 2  14186244                     NaN          NaN                  261.0
# 3  12177905                     NaN          NaN                  261.0
# 4  10887214                     NaN          NaN                  266.0
#
#    heatingorsystemtypeid  buildingclasstypeid  architecturalstyletypeid  \
# 0                    NaN                  NaN                       NaN
# 1                    NaN                  NaN                       NaN
# 2                    NaN                  NaN                       NaN
# 3                    2.0                  NaN                       NaN
# 4                    2.0                  NaN                       NaN
#
#    airconditioningtypeid       id  basementsqft  ...  id.1  logerror  \
# 0                    NaN  1727539           NaN  ...     0  0.025595
# 1                    NaN  1387261           NaN  ...     1  0.055619
# 2                    NaN    11677           NaN  ...     2  0.005383
# 3                    NaN  2288172           NaN  ...     3 -0.103410
# 4                    1.0  1970746           NaN  ...     4  0.006940
#
#    transactiondate  airconditioningdesc  architecturalstyledesc  \
# 0       2017-01-01                  NaN                     NaN
# 1       2017-01-01                  NaN                     NaN
# 2       2017-01-01                  NaN                     NaN
# 3       2017-01-01                  NaN                     NaN
# 4       2017-01-01              Central                     NaN
#
#    buildingclassdesc  heatingorsystemdesc        propertylandusedesc  \
# 0                NaN                  NaN  Single Family Residential
# 1                NaN                  NaN  Single Family Residential
# 2                NaN                  NaN  Single Family Residential
# 3                NaN              Central  Single Family Residential
# 4                NaN              Central                Condominium
#
#    storydesc  typeconstructiondesc
# 0        NaN                   NaN
# 1        NaN                   NaN
# 2        NaN                   NaN
# 3        NaN                   NaN
# 4        NaN                   NaN
#
# [5 rows x 69 columns]

# %%
# sorting by transaction date

df.sort_values('transactiondate', inplace = True)

# %%
# keeping only the unique parcel ids

df = df.drop_duplicates(subset = 'parcelid', keep = 'last')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 77381 entries, 0 to 77578
# Data columns (total 69 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   parcelid                      77381 non-null  int64
#  1   typeconstructiontypeid        222 non-null    float64
#  2   storytypeid                   50 non-null     float64
#  3   propertylandusetypeid         77381 non-null  float64
#  4   heatingorsystemtypeid         49440 non-null  float64
#  5   buildingclasstypeid           15 non-null     float64
#  6   architecturalstyletypeid      206 non-null    float64
#  7   airconditioningtypeid         24953 non-null  float64
#  8   id                            77381 non-null  int64
#  9   basementsqft                  50 non-null     float64
#  10  bathroomcnt                   77381 non-null  float64
#  11  bedroomcnt                    77381 non-null  float64
#  12  buildingqualitytypeid         49672 non-null  float64
#  13  calculatedbathnbr             76772 non-null  float64
#  14  decktypeid                    614 non-null    float64
#  15  finishedfloor1squarefeet      6023 non-null   float64
#  16  calculatedfinishedsquarefeet  77185 non-null  float64
#  17  finishedsquarefeet12          73749 non-null  float64
#  18  finishedsquarefeet13          41 non-null     float64
#  19  finishedsquarefeet15          3009 non-null   float64
#  20  finishedsquarefeet50          6023 non-null   float64
#  21  finishedsquarefeet6           386 non-null    float64
#  22  fips                          77381 non-null  float64
#  23  fireplacecnt                  8276 non-null   float64
#  24  fullbathcnt                   76772 non-null  float64
#  25  garagecarcnt                  25474 non-null  float64
#  26  garagetotalsqft               25474 non-null  float64
#  27  hashottuborspa                1538 non-null   float64
#  28  latitude                      77381 non-null  float64
#  29  longitude                     77381 non-null  float64
#  30  lotsizesquarefeet             69142 non-null  float64
#  31  poolcnt                       16137 non-null  float64
#  32  poolsizesum                   867 non-null    float64
#  33  pooltypeid10                  464 non-null    float64
#  34  pooltypeid2                   1074 non-null   float64
#  35  pooltypeid7                   15042 non-null  float64
#  36  propertycountylandusecode     77381 non-null  object
#  37  propertyzoningdesc            50331 non-null  object
#  38  rawcensustractandblock        77381 non-null  float64
#  39  regionidcity                  75910 non-null  float64
#  40  regionidcounty                77381 non-null  float64
#  41  regionidneighborhood          30890 non-null  float64
#  42  regionidzip                   77331 non-null  float64
#  43  roomcnt                       77381 non-null  float64
#  44  threequarterbathnbr           10096 non-null  float64
#  45  unitcnt                       50563 non-null  float64
#  46  yardbuildingsqft17            2388 non-null   float64
#  47  yardbuildingsqft26            70 non-null     float64
#  48  yearbuilt                     77118 non-null  float64
#  49  numberofstories               17560 non-null  float64
#  50  fireplaceflag                 172 non-null    float64
#  51  structuretaxvaluedollarcnt    77269 non-null  float64
#  52  taxvaluedollarcnt             77380 non-null  float64
#  53  assessmentyear                77381 non-null  float64
#  54  landtaxvaluedollarcnt         77379 non-null  float64
#  55  taxamount                     77376 non-null  float64
#  56  taxdelinquencyflag            2886 non-null   object
#  57  taxdelinquencyyear            2886 non-null   float64
#  58  censustractandblock           77137 non-null  float64
#  59  id.1                          77381 non-null  int64
#  60  logerror                      77381 non-null  float64
#  61  transactiondate               77381 non-null  object
#  62  airconditioningdesc           24953 non-null  object
#  63  architecturalstyledesc        206 non-null    object
#  64  buildingclassdesc             15 non-null     object
#  65  heatingorsystemdesc           49440 non-null  object
#  66  propertylandusedesc           77381 non-null  object
#  67  storydesc                     50 non-null     object
#  68  typeconstructiondesc          222 non-null    object
# dtypes: float64(55), int64(3), object(11)
# memory usage: 41.3+ MB

# %%
#describing the data

df.describe().T
# Out:
#                                 count          mean           std  \
# parcelid                      77381.0  1.300715e+07  3.481346e+06
# typeconstructiontypeid          222.0  6.040541e+00  5.572847e-01
# storytypeid                      50.0  7.000000e+00  0.000000e+00
# propertylandusetypeid         77381.0  2.618263e+02  5.141199e+00
# heatingorsystemtypeid         49440.0  3.920510e+00  3.592779e+00
# buildingclasstypeid              15.0  3.933333e+00  2.581989e-01
# architecturalstyletypeid        206.0  7.388350e+00  2.734542e+00
# airconditioningtypeid         24953.0  1.813289e+00  2.967894e+00
# id                            77381.0  1.495139e+06  8.609071e+05
# basementsqft                     50.0  6.797200e+02  6.897035e+02
# bathroomcnt                   77381.0  2.299130e+00  9.966507e-01
# bedroomcnt                    77381.0  3.053489e+00  1.139096e+00
# buildingqualitytypeid         49672.0  6.534587e+00  1.721953e+00
# calculatedbathnbr             76772.0  2.316867e+00  9.797549e-01
# decktypeid                      614.0  6.600000e+01  0.000000e+00
# finishedfloor1squarefeet       6023.0  1.366513e+03  6.713081e+02
# calculatedfinishedsquarefeet  77185.0  1.785220e+03  9.540493e+02
# finishedsquarefeet12          73749.0  1.760523e+03  9.340243e+02
# finishedsquarefeet13             41.0  1.389854e+03  1.235317e+02
# finishedsquarefeet15           3009.0  2.357792e+03  1.188775e+03
# finishedsquarefeet50           6023.0  1.381772e+03  7.264689e+02
# finishedsquarefeet6             386.0  2.082500e+03  1.240383e+03
# fips                          77381.0  6.048819e+03  2.074820e+01
# fireplacecnt                   8276.0  1.191155e+00  4.910796e-01
# fullbathcnt                   76772.0  2.250482e+00  9.665521e-01
# garagecarcnt                  25474.0  1.815459e+00  5.883449e-01
# garagetotalsqft               25474.0  3.501120e+02  2.616816e+02
# hashottuborspa                 1538.0  1.000000e+00  0.000000e+00
# latitude                      77381.0  3.400837e+07  2.653888e+05
# longitude                     77381.0 -1.182036e+08  3.594826e+05
# lotsizesquarefeet             69142.0  2.996928e+04  1.233711e+05
# poolcnt                       16137.0  1.000000e+00  0.000000e+00
# poolsizesum                     867.0  5.179170e+02  1.567160e+02
# pooltypeid10                    464.0  1.000000e+00  0.000000e+00
# pooltypeid2                    1074.0  1.000000e+00  0.000000e+00
# pooltypeid7                   15042.0  1.000000e+00  0.000000e+00
# rawcensustractandblock        77381.0  6.049129e+07  2.059052e+05
# regionidcity                  75910.0  3.367124e+04  4.716982e+04
# regionidcounty                77381.0  2.534158e+03  8.015934e+02
# regionidneighborhood          30890.0  1.877349e+05  1.651188e+05
# regionidzip                   77331.0  9.658709e+04  3.798347e+03
# roomcnt                       77381.0  1.476952e+00  2.824386e+00
# threequarterbathnbr           10096.0  1.009608e+00  1.186301e-01
# unitcnt                       50563.0  1.110021e+00  1.171154e+00
# yardbuildingsqft17             2388.0  3.054112e+02  2.383928e+02
# yardbuildingsqft26               70.0  2.163857e+02  1.901775e+02
# yearbuilt                     77118.0  1.968636e+03  2.378603e+01
# numberofstories               17560.0  1.434738e+00  5.445687e-01
# fireplaceflag                   172.0  1.000000e+00  0.000000e+00
# structuretaxvaluedollarcnt    77269.0  1.893145e+05  2.300874e+05
# taxvaluedollarcnt             77380.0  4.901345e+05  6.534440e+05
# assessmentyear                77381.0  2.016000e+03  0.000000e+00
# landtaxvaluedollarcnt         77379.0  3.010954e+05  4.925960e+05
# taxamount                     77376.0  5.995532e+03  7.622844e+03
# taxdelinquencyyear             2886.0  1.408732e+01  2.185663e+00
# censustractandblock           77137.0  6.049673e+13  1.535242e+12
# id.1                          77381.0  3.884789e+04  2.240216e+04
# logerror                      77381.0  1.662499e-02  1.701908e-01
#
#                                        min           25%           50%  \
# parcelid                      1.071186e+07  1.153830e+07  1.253157e+07
# typeconstructiontypeid        4.000000e+00  6.000000e+00  6.000000e+00
# storytypeid                   7.000000e+00  7.000000e+00  7.000000e+00
# propertylandusetypeid         3.100000e+01  2.610000e+02  2.610000e+02
# heatingorsystemtypeid         1.000000e+00  2.000000e+00  2.000000e+00
# buildingclasstypeid           3.000000e+00  4.000000e+00  4.000000e+00
# architecturalstyletypeid      2.000000e+00  7.000000e+00  7.000000e+00
# airconditioningtypeid         1.000000e+00  1.000000e+00  1.000000e+00
# id                            3.490000e+02  7.520700e+05  1.497932e+06
# basementsqft                  3.800000e+01  2.730000e+02  5.150000e+02
# bathroomcnt                   0.000000e+00  2.000000e+00  2.000000e+00
# bedroomcnt                    0.000000e+00  2.000000e+00  3.000000e+00
# buildingqualitytypeid         1.000000e+00  6.000000e+00  6.000000e+00
# calculatedbathnbr             1.000000e+00  2.000000e+00  2.000000e+00
# decktypeid                    6.600000e+01  6.600000e+01  6.600000e+01
# finishedfloor1squarefeet      4.400000e+01  9.550000e+02  1.257000e+03
# calculatedfinishedsquarefeet  1.280000e+02  1.182000e+03  1.543000e+03
# finishedsquarefeet12          1.280000e+02  1.172000e+03  1.523000e+03
# finishedsquarefeet13          1.056000e+03  1.344000e+03  1.440000e+03
# finishedsquarefeet15          5.980000e+02  1.625000e+03  2.094000e+03
# finishedsquarefeet50          4.400000e+01  9.560000e+02  1.259000e+03
# finishedsquarefeet6           3.800000e+02  9.937500e+02  1.812500e+03
# fips                          6.037000e+03  6.037000e+03  6.037000e+03
# fireplacecnt                  1.000000e+00  1.000000e+00  1.000000e+00
# fullbathcnt                   1.000000e+00  2.000000e+00  2.000000e+00
# garagecarcnt                  0.000000e+00  2.000000e+00  2.000000e+00
# garagetotalsqft               0.000000e+00  0.000000e+00  4.360000e+02
# hashottuborspa                1.000000e+00  1.000000e+00  1.000000e+00
# latitude                      3.333953e+07  3.381457e+07  3.402200e+07
# longitude                    -1.194754e+08 -1.184153e+08 -1.181808e+08
# lotsizesquarefeet             2.360000e+02  5.700000e+03  7.206000e+03
# poolcnt                       1.000000e+00  1.000000e+00  1.000000e+00
# poolsizesum                   2.400000e+01  4.240000e+02  5.000000e+02
# pooltypeid10                  1.000000e+00  1.000000e+00  1.000000e+00
# pooltypeid2                   1.000000e+00  1.000000e+00  1.000000e+00
# pooltypeid7                   1.000000e+00  1.000000e+00  1.000000e+00
# rawcensustractandblock        6.037101e+07  6.037311e+07  6.037603e+07
# regionidcity                  3.491000e+03  1.244700e+04  2.521800e+04
# regionidcounty                1.286000e+03  1.286000e+03  3.101000e+03
# regionidneighborhood          6.952000e+03  4.673600e+04  1.188490e+05
# regionidzip                   9.598200e+04  9.619300e+04  9.638900e+04
# roomcnt                       0.000000e+00  0.000000e+00  0.000000e+00
# threequarterbathnbr           1.000000e+00  1.000000e+00  1.000000e+00
# unitcnt                       1.000000e+00  1.000000e+00  1.000000e+00
# yardbuildingsqft17            1.100000e+01  1.700000e+02  2.510000e+02
# yardbuildingsqft26            1.200000e+01  6.150000e+01  1.645000e+02
# yearbuilt                     1.824000e+03  1.953000e+03  1.970000e+03
# numberofstories               1.000000e+00  1.000000e+00  1.000000e+00
# fireplaceflag                 1.000000e+00  1.000000e+00  1.000000e+00
# structuretaxvaluedollarcnt    4.400000e+01  8.426500e+04  1.364990e+05
# taxvaluedollarcnt             1.000000e+03  2.070000e+05  3.589755e+05
# assessmentyear                2.016000e+03  2.016000e+03  2.016000e+03
# landtaxvaluedollarcnt         1.610000e+02  8.550400e+04  2.033720e+05
# taxamount                     1.992000e+01  2.715632e+03  4.450695e+03
# taxdelinquencyyear            3.000000e+00  1.400000e+01  1.500000e+01
# censustractandblock           6.037101e+13  6.037311e+13  6.037603e+13
# id.1                          0.000000e+00  1.946000e+04  3.886900e+04
# logerror                     -4.655420e+00 -2.437679e-02  6.626972e-03
#
#                                        75%           max
# parcelid                      1.421183e+07  1.676893e+08
# typeconstructiontypeid        6.000000e+00  1.300000e+01
# storytypeid                   7.000000e+00  7.000000e+00
# propertylandusetypeid         2.660000e+02  2.750000e+02
# heatingorsystemtypeid         7.000000e+00  2.400000e+01
# buildingclasstypeid           4.000000e+00  4.000000e+00
# architecturalstyletypeid      7.000000e+00  2.100000e+01
# airconditioningtypeid         1.000000e+00  1.300000e+01
# id                            2.240535e+06  2.982274e+06
# basementsqft                  7.965000e+02  3.560000e+03
# bathroomcnt                   3.000000e+00  1.800000e+01
# bedroomcnt                    4.000000e+00  1.600000e+01
# buildingqualitytypeid         8.000000e+00  1.200000e+01
# calculatedbathnbr             3.000000e+00  1.800000e+01
# decktypeid                    6.600000e+01  6.600000e+01
# finishedfloor1squarefeet      1.615000e+03  6.912000e+03
# calculatedfinishedsquarefeet  2.113000e+03  3.564000e+04
# finishedsquarefeet12          2.076000e+03  2.192900e+04
# finishedsquarefeet13          1.440000e+03  1.560000e+03
# finishedsquarefeet15          2.838000e+03  3.564000e+04
# finishedsquarefeet50          1.621500e+03  1.246700e+04
# finishedsquarefeet6           3.053500e+03  5.598000e+03
# fips                          6.059000e+03  6.111000e+03
# fireplacecnt                  1.000000e+00  5.000000e+00
# fullbathcnt                   3.000000e+00  1.800000e+01
# garagecarcnt                  2.000000e+00  1.400000e+01
# garagetotalsqft               4.930000e+02  4.251000e+03
# hashottuborspa                1.000000e+00  1.000000e+00
# latitude                      3.417439e+07  3.481877e+07
# longitude                    -1.179284e+08 -1.175546e+08
# lotsizesquarefeet             1.183100e+04  6.971010e+06
# poolcnt                       1.000000e+00  1.000000e+00
# poolsizesum                   6.000000e+02  1.500000e+03
# pooltypeid10                  1.000000e+00  1.000000e+00
# pooltypeid2                   1.000000e+00  1.000000e+00
# pooltypeid7                   1.000000e+00  1.000000e+00
# rawcensustractandblock        6.059042e+07  6.111009e+07
# regionidcity                  4.545700e+04  3.965560e+05
# regionidcounty                3.101000e+03  3.101000e+03
# regionidneighborhood          2.747650e+05  7.641670e+05
# regionidzip                   9.698700e+04  3.996750e+05
# roomcnt                       0.000000e+00  1.500000e+01
# threequarterbathnbr           1.000000e+00  7.000000e+00
# unitcnt                       1.000000e+00  2.370000e+02
# yardbuildingsqft17            3.640000e+02  3.191000e+03
# yardbuildingsqft26            3.105000e+02  8.680000e+02
# yearbuilt                     1.987000e+03  2.016000e+03
# numberofstories               2.000000e+00  6.000000e+00
# fireplaceflag                 1.000000e+00  1.000000e+00
# structuretaxvaluedollarcnt    2.187870e+05  1.142179e+07
# taxvaluedollarcnt             5.690015e+05  4.906124e+07
# assessmentyear                2.016000e+03  2.016000e+03
# landtaxvaluedollarcnt         3.667965e+05  4.895220e+07
# taxamount                     6.927790e+03  5.866393e+05
# taxdelinquencyyear            1.500000e+01  9.900000e+01
# censustractandblock           6.059042e+13  4.830301e+14
# id.1                          5.825200e+04  7.761200e+04
# logerror                      3.920313e-02  5.262999e+00

# %%
# shape of df

df.shape
# Out:
# (77381, 69)

# %%
# some distributions : year built

df['yearbuilt'].min(), df['yearbuilt'].max()
# Out:
# (1824.0, 2016.0)

# %%
# some distributions : number of fireplaces

df['fireplacecnt'].max(), df['fireplacecnt'].min()
# Out:
# (5.0, 1.0)

# %%
## some distributions : number of fireplaces

df['basementsqft'].max(), df['basementsqft'].min()
# Out:
# (3560.0, 38.0)

# %%
df.drop(columns = ['id.1', 'parcelid'], inplace = True)

# %% [markdown]
# ### 3. Write a function that takes in a dataframe of observations and attributes and returns a dataframe where each row is an atttribute name, the first column is the number of rows with missing values for that attribute, and the second column is percent of total rows that have missing values for that attribute.
# Run the function and document takeaways from this on how you want to handle missing values.

# %%
len(df)
# Out:
# 77381

# %%
# putting all the columns into a list

all_col = ['typeconstructiontypeid', 'storytypeid', 'propertylandusetypeid',
           'heatingorsystemtypeid','buildingclasstypeid', 'airconditioningtypeid',
           'id', 'basementsqft', 'bathroomcnt', 'bedroomcnt','buildingqualitytypeid',
           'calculatedbathnbr', 'decktypeid', 'finishedfloor1squarefeet',
           'calculatedfinishedsquarefeet', 'finishedsquarefeet12', 
           'finishedsquarefeet13', 'finishedsquarefeet15', 'finishedsquarefeet50',
           'finishedsquarefeet6', 'fips', 'fireplacecnt', 'fullbathcnt',
           'garagecarcnt','garagetotalsqft', 'hashottuborspa', 'latitude',
           'longitude', 'lotsizesquarefeet', 'poolcnt', 'poolsizesum',
           'pooltypeid10', 'pooltypeid2', 'pooltypeid7', 'propertycountylandusecode',
           'fireplaceflag', 'structuretaxvaluedollarcnt','propertyzoningdesc',
           'rawcensustractandblock', 'regionidcity', 'regionidcounty', 
           'regionidneighborhood','regionidzip', 'roomcnt','threequarterbathnbr', 
           'unitcnt', 'yardbuildingsqft17', 'yardbuildingsqft26', 'yearbuilt',
           'numberofstories', 'taxvaluedollarcnt', 'assessmentyear', 
           'landtaxvaluedollarcnt', 'taxamount', 'taxdelinquencyyear', 
           'censustractandblock', 'logerror']

# %%
# # converting 0, blanks, nulls to nan

# df = df.replace([0, ' ', 'NULL'], np.nan)

# df.head(1)

# %%
# # creating df of rows with null values

# missing_rows = df.isna()
# missing_rows.head(1)

# %%
# # assuring that missing_rows is boolean
# missing_rows.dtypes

# %%
# # finding sum of each row

# missing_num_rows = missing_rows.sum()
# missing_num_rows

# %%
# # finding the percentage of missing rows

# pc_missing_rows = round((missing_num_rows / len(df)), 2)
# pc_missing_rows

# %%
# # alternate to the above

# dnd = (df.isna().mean().round(4))
# dnd

# %%
# # creating dataframe with the missing row-numbers
# missing = pd.DataFrame(missing_num_rows)
# missing

# %%
# # adding the pc to the missing df

# missing['pc_missing'] = pc_missing_rows
# missing

# %%
# # renaming the 0 column

# missing = missing.rename(columns = {0 : 'num_missing_rows'})
# missing

# %%
# # sorting by pc_missing date

# missing.sort_values('pc_missing', ascending = False, inplace = True)
# missing

# %%
# in-class example 

def null_counter(df):
    
    num_coluns = ['name', 'num_rows_missing', 'pc_rows_missing']
    new_df = pd.DataFrame(columns = num_coluns)
    
    for col in list(df.columns):
        num_missing = df[col].isna().sum()
        
        pc_missing = num_missing / df.shape[0]
        
        add_df = pd.DataFrame([{'name' : col, 'num_rows_missing': num_missing, 'pc_rows_missing' : pc_missing}])
        
        new_df = pd.concat([new_df, add_df], axis = 0)
        
    new_df.set_index('name', inplace = True)
    
    return new_df

# %%
# in-class example 
null_df = null_counter(df)

null_df.sort_values(by = 'pc_rows_missing', ascending = False)
# Out:
#                              num_rows_missing  pc_rows_missing
# name
# buildingclassdesc                       77366         0.999806
# buildingclasstypeid                     77366         0.999806
# finishedsquarefeet13                    77340         0.999470
# storydesc                               77331         0.999354
# basementsqft                            77331         0.999354
# storytypeid                             77331         0.999354
# yardbuildingsqft26                      77311         0.999095
# fireplaceflag                           77209         0.997777
# architecturalstyletypeid                77175         0.997338
# architecturalstyledesc                  77175         0.997338
# typeconstructiontypeid                  77159         0.997131
# typeconstructiondesc                    77159         0.997131
# finishedsquarefeet6                     76995         0.995012
# pooltypeid10                            76917         0.994004
# decktypeid                              76767         0.992065
# poolsizesum                             76514         0.988796
# pooltypeid2                             76307         0.986121
# hashottuborspa                          75843         0.980124
# yardbuildingsqft17                      74993         0.969140
# taxdelinquencyflag                      74495         0.962704
# taxdelinquencyyear                      74495         0.962704
# finishedsquarefeet15                    74372         0.961114
# finishedsquarefeet50                    71358         0.922164
# finishedfloor1squarefeet                71358         0.922164
# fireplacecnt                            69105         0.893049
# threequarterbathnbr                     67285         0.869529
# pooltypeid7                             62339         0.805611
# poolcnt                                 61244         0.791460
# numberofstories                         59821         0.773071
# airconditioningdesc                     52428         0.677531
# airconditioningtypeid                   52428         0.677531
# garagetotalsqft                         51907         0.670798
# garagecarcnt                            51907         0.670798
# regionidneighborhood                    46491         0.600806
# heatingorsystemtypeid                   27941         0.361083
# heatingorsystemdesc                     27941         0.361083
# buildingqualitytypeid                   27709         0.358085
# propertyzoningdesc                      27050         0.349569
# unitcnt                                 26818         0.346571
# lotsizesquarefeet                        8239         0.106473
# finishedsquarefeet12                     3632         0.046937
# regionidcity                             1471         0.019010
# calculatedbathnbr                         609         0.007870
# fullbathcnt                               609         0.007870
# yearbuilt                                 263         0.003399
# censustractandblock                       244         0.003153
# calculatedfinishedsquarefeet              196         0.002533
# structuretaxvaluedollarcnt                112         0.001447
# regionidzip                                50         0.000646
# taxamount                                   5         0.000065
# landtaxvaluedollarcnt                       2         0.000026
# taxvaluedollarcnt                           1         0.000013
# roomcnt                                     0         0.000000
# transactiondate                             0         0.000000
# propertylandusetypeid                       0         0.000000
# propertylandusedesc                         0         0.000000
# fips                                        0         0.000000
# latitude                                    0         0.000000
# bedroomcnt                                  0         0.000000
# logerror                                    0         0.000000
# longitude                                   0         0.000000
# assessmentyear                              0         0.000000
# id                                          0         0.000000
# propertycountylandusecode                   0         0.000000
# bathroomcnt                                 0         0.000000
# rawcensustractandblock                      0         0.000000
# regionidcounty                              0         0.000000

# %%
# function to do the above 
# null_counter

def missing_rows(df):
    
    # converting 0, blanks, nulls to nan
    df = df.replace([' ', 'NULL'], np.nan)

    # creating df of rows with null values
    missing_rows = df.isna()
    
    # finding sum of each row
    missing_num_rows = missing_rows.sum()
    
    # finding the percentage of missing rows
    pc_missing_rows = (df.isna().mean().round(4))
    
    # creating dataframe with the missing row-numbers
    df = pd.DataFrame(missing_num_rows)
    
    # adding the pc to the missing df
    df['pc_missing'] = pc_missing_rows

    # renaming the 0 column
    df = df.rename(columns = {0 : 'num_missing_rows'})
    
    # sorting to have lowest pc missing at the top
    df.sort_values('pc_missing', ascending = False, inplace = True)
    
    return df

# %%
missing = missing_rows(df)
missing.head()
# Out:
#                       num_missing_rows  pc_missing
# buildingclassdesc                77366      0.9998
# buildingclasstypeid              77366      0.9998
# finishedsquarefeet13             77340      0.9995
# storydesc                        77331      0.9994
# basementsqft                     77331      0.9994

# %% [markdown]
# ## Prepare
#
# ### 1 . Remove any properties that are likely to be something other than single unit properties. (e.g. no duplexes, no land/lot, ...). There are multiple ways to estimate that a property is a single unit, and there is not a single "right" answer.

# %%
# looking at the columns

df.columns
# Out:
# Index(['typeconstructiontypeid', 'storytypeid', 'propertylandusetypeid',
#        'heatingorsystemtypeid', 'buildingclasstypeid',
#        'architecturalstyletypeid', 'airconditioningtypeid', 'id',
#        'basementsqft', 'bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid',
#        'calculatedbathnbr', 'decktypeid', 'finishedfloor1squarefeet',
#        'calculatedfinishedsquarefeet', 'finishedsquarefeet12',
#        'finishedsquarefeet13', 'finishedsquarefeet15', 'finishedsquarefeet50',
#        'finishedsquarefeet6', 'fips', 'fireplacecnt', 'fullbathcnt',
#        'garagecarcnt', 'garagetotalsqft', 'hashottuborspa', 'latitude',
#        'longitude', 'lotsizesquarefeet', 'poolcnt', 'poolsizesum',
#        'pooltypeid10', 'pooltypeid2', 'pooltypeid7',
#        'propertycountylandusecode', 'propertyzoningdesc',
#        'rawcensustractandblock', 'regionidcity', 'regionidcounty',
#        'regionidneighborhood', 'regionidzip', 'roomcnt', 'threequarterbathnbr',
#        'unitcnt', 'yardbuildingsqft17', 'yardbuildingsqft26', 'yearbuilt',
#        'numberofstories', 'fireplaceflag', 'structuretaxvaluedollarcnt',
#        'taxvaluedollarcnt', 'assessmentyear', 'landtaxvaluedollarcnt',
#        'taxamount', 'taxdelinquencyflag', 'taxdelinquencyyear',
#        'censustractandblock', 'logerror', 'transactiondate',
#        'airconditioningdesc', 'architecturalstyledesc', 'buildingclassdesc',
#        'heatingorsystemdesc', 'propertylandusedesc', 'storydesc',
#        'typeconstructiondesc'],
#       dtype='object')

# %%
# looking at prperty types

df['propertylandusedesc'].value_counts()
# Out:
# Single Family Residential                     52320
# Condominium                                   19294
# Duplex (2 Units, Any Combination)              2009
# Planned Unit Development                       1944
# Quadruplex (4 Units, Any Combination)           727
# Triplex (3 Units, Any Combination)              535
# Cluster Home                                    333
# Mobile Home                                      74
# Manufactured, Modular, Prefabricated Homes       58
# Residential General                              37
# Cooperative                                      29
# Commercial/Office/Residential Mixed Used         15
# Townhouse                                         6
# Name: propertylandusedesc, dtype: int64

# %%
#keeping only units of Single Family Residential 

# df = df[df['propertylandusedesc'] == 'Single Family Residential']

# %% [markdown]
# Decided against SFR as the separator, bc many SFRs have +1 unit.

# %%
# finding how many properties have how many units

df['unitcnt'].value_counts()
# Out:
# 1.0      47293
# 2.0       2018
# 4.0        723
# 3.0        525
# 45.0         1
# 42.0         1
# 6.0          1
# 237.0        1
# Name: unitcnt, dtype: int64

# %%
# keeping only properties with 1 unit

df = df[df['unitcnt'] == 1]
df.shape
# Out:
# (47293, 67)

# %% [markdown]
# ## 2 . Create a function that will drop rows or columns based on the percent of values that are missing :
# ```handle_missing_values(df, prop_required_column, prop_required_row)```.
#
#
#     -The input:
#         A dataframe
#
#         A number between 0 and 1 that represents the proportion of rows for each column with non-missing values This number is the amount required to keep the column. For example, if prop_required_column = .6, then you are requiring a column to have at least 60% of values not-NA (no more than 40% missing).
#
#         A number between 0 and 1 that represents the proportion of columns/variables for each row with non-missing values required to keep the row. For example, if prop_required_row = .75, then you are requiring a row to have at least 75% of variables with a non-missing value (no more that 25% missing).
#
#     -The output:
#         The dataframe with the columns and rows dropped as indicated. Be sure to drop the columns prior to the rows in your function.
#
#     -hint:
#         Look up the dropna documentation.
#         You will want to compute a threshold from your input values (prop_required) and total number of rows or columns.

# %% [markdown]
# ### alternate nº3

# %%
# alternate function by Bill

def drops(df, thresh1, thresh2):
    
    # dropping if nulls more than a certain amount
    # th1 = rows, th2 = col
    
    loop = list(range(0, len(df.axes[1])))
    adf = []
    
    # chooses column from 0 to x
    for i in loop: 
        x = df.iloc[:,i].isna().sum()
        
        #appending to above blank list
        adf.append(x)
        
    fjf = []
    for i in adf:
        x = i / len(df.axes[0])
        # diving nulls by num rows to get a pc
        fjf.append(x)
        
    # make lists into arrays
    indices = np.array(fjf)
    indices2 = np.where(indices > thresh1)[0]
    
    # array of indices of columsn to drop
    df = df.drop(df.columns[indices2], axis = 1)
    
    ddd = []
    x = df.isnull().sum(axis = 1)
    for i in x:
        # going into the rows, counting rows for each col
        yo = i / len(x) # gets pc of nulls in row
        
        ddd.append(yo)
    indices3 = np.array(ddd)
    indices4 = np.where(indices3 > thresh2)[0]
    
    # dropping indices4
    df = df.drop(indices4)
    
    return df

# %%
df1 = drops(df, 0.6, 0.6)
df1.head(1)
# Out:
#    propertylandusetypeid  heatingorsystemtypeid  airconditioningtypeid  \
# 3                  261.0                    2.0                    NaN
#
#         id  bathroomcnt  bedroomcnt  buildingqualitytypeid  calculatedbathnbr  \
# 3  2288172          3.0         4.0                    8.0                3.0
#
#    calculatedfinishedsquarefeet  finishedsquarefeet12  ...  taxvaluedollarcnt  \
# 3                        2376.0                2376.0  ...           145143.0
#
#    assessmentyear  landtaxvaluedollarcnt  taxamount  censustractandblock  \
# 3          2016.0                36225.0    1777.51         6.037300e+13
#
#   logerror transactiondate  airconditioningdesc  heatingorsystemdesc  \
# 3 -0.10341      2017-01-01                  NaN              Central
#
#          propertylandusedesc
# 3  Single Family Residential
#
# [1 rows x 36 columns]

# %%
# # giving the index a name

# missing.index.names = ['descriptor']


# # reset index

# missing.reset_index(inplace = True)
# missing.head(1)

# %%
# # looking at rows with less than 55% missing values
# missing[missing['pc_missing'] < 0.55].head(3)

# %%
# missing.iloc[0]
    
#     missing.loc[(missing['index'] == col) &
#                 (missing['pc_missing'] < 0.6)]

# %%
# # making a function to access each row

# def thing(df):
#     for col in all_col:

#         # accessing each row in the index
#         df = df.loc[(df['descriptor'] == col) &
#                    (np.where(df['pc_missing'] < 0.55, 1, 0))]

#     return df

# %%
# thing(df)

# %%
# np.where(missing['pc_missing'] < 0.55, 1, 0)

# %%
# for col in all_col:
#     df = df.loc[(df['descriptor'] == col)]
#     df

# %%
df.head()
# Out:
#     typeconstructiontypeid  storytypeid  propertylandusetypeid  \
# 3                      NaN          NaN                  261.0
# 4                      NaN          NaN                  266.0
# 6                      NaN          NaN                  261.0
# 7                      NaN          NaN                  261.0
# 70                     NaN          NaN                  261.0
#
#     heatingorsystemtypeid  buildingclasstypeid  architecturalstyletypeid  \
# 3                     2.0                  NaN                       NaN
# 4                     2.0                  NaN                       NaN
# 6                     2.0                  NaN                       NaN
# 7                     NaN                  NaN                       NaN
# 70                    7.0                  NaN                       NaN
#
#     airconditioningtypeid       id  basementsqft  bathroomcnt  ...  \
# 3                     NaN  2288172           NaN          3.0  ...
# 4                     1.0  1970746           NaN          3.0  ...
# 6                     1.0   781532           NaN          3.0  ...
# 7                     NaN   870991           NaN          1.0  ...
# 70                    NaN  1061201           NaN          1.0  ...
#
#     censustractandblock  logerror  transactiondate  airconditioningdesc  \
# 3          6.037300e+13 -0.103410       2017-01-01                  NaN
# 4          6.037124e+13  0.006940       2017-01-01              Central
# 6          6.037461e+13 -0.001011       2017-01-01              Central
# 7          6.037302e+13  0.101723       2017-01-01                  NaN
# 70         6.037110e+13  0.021262       2017-01-02                  NaN
#
#     architecturalstyledesc  buildingclassdesc  heatingorsystemdesc  \
# 3                      NaN                NaN              Central
# 4                      NaN                NaN              Central
# 6                      NaN                NaN              Central
# 7                      NaN                NaN                  NaN
# 70                     NaN                NaN           Floor/Wall
#
#           propertylandusedesc  storydesc  typeconstructiondesc
# 3   Single Family Residential        NaN                   NaN
# 4                 Condominium        NaN                   NaN
# 6   Single Family Residential        NaN                   NaN
# 7   Single Family Residential        NaN                   NaN
# 70  Single Family Residential        NaN                   NaN
#
# [5 rows x 67 columns]

# %%
# # combining the two dfs

# #making list of df and missing
# frames = [df, missing]

# # combining into new df
# new = pd.concat(frames)

# new.drop(columns = ['descriptor'], inplace = True)

# display(new)
# df.shape, new.shape, missing.shape

# %%
# new2 = pd.concat([df, missing], axis = 1, join = 'outer')

# %% [markdown]
# Returns 47323 rows × 70 columns.

# %%
# df = df.T
# df

# %%
# # making list of df and missing
# frames = [df, missing]

# # missing.drop(columns = ['descriptor'], inplace = True)

# # combining into new df
# new = pd.concat(frames, axis = 0, join = 'outer')

# new

# %%
# df.shape, new.shape, missing.shape

dfo = df.copy()

# %%
dfo = dfo.append(missing, ignore_index=True)
dfo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47360 entries, 0 to 47359
# Data columns (total 69 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   typeconstructiontypeid        0 non-null      float64
#  1   storytypeid                   0 non-null      float64
#  2   propertylandusetypeid         47293 non-null  float64
#  3   heatingorsystemtypeid         46565 non-null  float64
#  4   buildingclasstypeid           8 non-null      float64
#  5   architecturalstyletypeid      0 non-null      float64
#  6   airconditioningtypeid         22020 non-null  float64
#  7   id                            47293 non-null  float64
#  8   basementsqft                  0 non-null      float64
#  9   bathroomcnt                   47293 non-null  float64
#  10  bedroomcnt                    47293 non-null  float64
#  11  buildingqualitytypeid         46803 non-null  float64
#  12  calculatedbathnbr             47247 non-null  float64
#  13  decktypeid                    0 non-null      float64
#  14  finishedfloor1squarefeet      0 non-null      float64
#  15  calculatedfinishedsquarefeet  47286 non-null  float64
#  16  finishedsquarefeet12          47246 non-null  float64
#  17  finishedsquarefeet13          0 non-null      float64
#  18  finishedsquarefeet15          35 non-null     float64
#  19  finishedsquarefeet50          0 non-null      float64
#  20  finishedsquarefeet6           5 non-null      float64
#  21  fips                          47293 non-null  float64
#  22  fireplacecnt                  0 non-null      float64
#  23  fullbathcnt                   47247 non-null  float64
#  24  garagecarcnt                  10 non-null     float64
#  25  garagetotalsqft               10 non-null     float64
#  26  hashottuborspa                0 non-null      float64
#  27  latitude                      47293 non-null  float64
#  28  longitude                     47293 non-null  float64
#  29  lotsizesquarefeet             46058 non-null  float64
#  30  poolcnt                       11570 non-null  float64
#  31  poolsizesum                   0 non-null      float64
#  32  pooltypeid10                  0 non-null      float64
#  33  pooltypeid2                   0 non-null      float64
#  34  pooltypeid7                   11549 non-null  float64
#  35  propertycountylandusecode     47293 non-null  object
#  36  propertyzoningdesc            47063 non-null  object
#  37  rawcensustractandblock        47293 non-null  float64
#  38  regionidcity                  46252 non-null  float64
#  39  regionidcounty                47293 non-null  float64
#  40  regionidneighborhood          24082 non-null  float64
#  41  regionidzip                   47273 non-null  float64
#  42  roomcnt                       47293 non-null  float64
#  43  threequarterbathnbr           0 non-null      float64
#  44  unitcnt                       47293 non-null  float64
#  45  yardbuildingsqft17            0 non-null      float64
#  46  yardbuildingsqft26            0 non-null      float64
#  47  yearbuilt                     47279 non-null  float64
#  48  numberofstories               20 non-null     float64
#  49  fireplaceflag                 0 non-null      float64
#  50  structuretaxvaluedollarcnt    47230 non-null  float64
#  51  taxvaluedollarcnt             47293 non-null  float64
#  52  assessmentyear                47293 non-null  float64
#  53  landtaxvaluedollarcnt         47293 non-null  float64
#  54  taxamount                     47289 non-null  float64
#  55  taxdelinquencyflag            2198 non-null   object
#  56  taxdelinquencyyear            2198 non-null   float64
#  57  censustractandblock           47177 non-null  float64
#  58  logerror                      47293 non-null  float64
#  59  transactiondate               47293 non-null  object
#  60  airconditioningdesc           22020 non-null  object
#  61  architecturalstyledesc        0 non-null      object
#  62  buildingclassdesc             8 non-null      object
#  63  heatingorsystemdesc           46565 non-null  object
#  64  propertylandusedesc           47293 non-null  object
#  65  storydesc                     0 non-null      object
#  66  typeconstructiondesc          0 non-null      object
#  67  num_missing_rows              67 non-null     float64
#  68  pc_missing                    67 non-null     float64
# dtypes: float64(58), object(11)
# memory usage: 24.9+ MB
# /var/folders/v1/7y2hc6q17wl2rjlpg8h9g78h0000gn/T/ipykernel_2123/971790651.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dfo = dfo.append(missing, ignore_index=True)

# %%
missing.head()
# Out:
#                       num_missing_rows  pc_missing
# buildingclassdesc                77366      0.9998
# buildingclasstypeid              77366      0.9998
# finishedsquarefeet13             77340      0.9995
# storydesc                        77331      0.9994
# basementsqft                     77331      0.9994

# %%
missing[missing['pc_missing'] > 0.55]
# Out:
#                           num_missing_rows  pc_missing
# buildingclassdesc                    77366      0.9998
# buildingclasstypeid                  77366      0.9998
# finishedsquarefeet13                 77340      0.9995
# storydesc                            77331      0.9994
# basementsqft                         77331      0.9994
# storytypeid                          77331      0.9994
# yardbuildingsqft26                   77311      0.9991
# fireplaceflag                        77209      0.9978
# architecturalstyletypeid             77175      0.9973
# architecturalstyledesc               77175      0.9973
# typeconstructiontypeid               77159      0.9971
# typeconstructiondesc                 77159      0.9971
# finishedsquarefeet6                  76995      0.9950
# pooltypeid10                         76917      0.9940
# decktypeid                           76767      0.9921
# poolsizesum                          76514      0.9888
# pooltypeid2                          76307      0.9861
# hashottuborspa                       75843      0.9801
# yardbuildingsqft17                   74993      0.9691
# taxdelinquencyflag                   74495      0.9627
# taxdelinquencyyear                   74495      0.9627
# finishedsquarefeet15                 74372      0.9611
# finishedsquarefeet50                 71358      0.9222
# finishedfloor1squarefeet             71358      0.9222
# fireplacecnt                         69105      0.8930
# threequarterbathnbr                  67285      0.8695
# pooltypeid7                          62339      0.8056
# poolcnt                              61244      0.7915
# numberofstories                      59821      0.7731
# airconditioningdesc                  52428      0.6775
# airconditioningtypeid                52428      0.6775
# garagetotalsqft                      51907      0.6708
# garagecarcnt                         51907      0.6708
# regionidneighborhood                 46491      0.6008

# %%
# this is the way to 

ciao = missing[missing['pc_missing'] > 0.55].index.to_list()
df.drop(columns = ciao, inplace = True)
df.shape
# Out:
# (47293, 33)

# %%
# counting how many nans are left

df.isna().sum()
# Out:
# propertylandusetypeid              0
# heatingorsystemtypeid            728
# id                                 0
# bathroomcnt                        0
# bedroomcnt                         0
# buildingqualitytypeid            490
# calculatedbathnbr                 46
# calculatedfinishedsquarefeet       7
# finishedsquarefeet12              47
# fips                               0
# fullbathcnt                       46
# latitude                           0
# longitude                          0
# lotsizesquarefeet               1235
# propertycountylandusecode          0
# propertyzoningdesc               230
# rawcensustractandblock             0
# regionidcity                    1041
# regionidcounty                     0
# regionidzip                       20
# roomcnt                            0
# unitcnt                            0
# yearbuilt                         14
# structuretaxvaluedollarcnt        63
# taxvaluedollarcnt                  0
# assessmentyear                     0
# landtaxvaluedollarcnt              0
# taxamount                          4
# censustractandblock              116
# logerror                           0
# transactiondate                    0
# heatingorsystemdesc              728
# propertylandusedesc                0
# dtype: int64

# %%
# missing[missing['pc_missing'] > 0.55]

# %%
# drops a row if all that it has are NaNs

# df.dropna(thresh = 27, how = 'any', axis = 0)

# df.dropna(thresh = number of remaining cols * entered_number (0.844), axis = 0)

# %%
# function

def handle_missing_values(df, prop_required_column, prop_required_row):
    
    # copy of original df
    df2 = df.copy()
    
    # list of all columns with +55pc missing values
    ciao = missing[missing['pc_missing'] > prop_required_column].index.to_list()
    
    # dropping 
    #dfo.dropna(columns = ciao)
    
    # dropping rows with pc missing values
    dfo.dropna(thresh = (dfo.shape[0] * prop_required_row), how = 'any', axis = 0)
    
    return dfo

# %%
handle_missing_values(df, 0.8, 0.6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 handle_missing_values(df, 0.8, 0.6)
#
# NameError: name 'df' is not defined

# %%
dfo.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 dfo.isnull().sum()
#
# NameError: name 'dfo' is not defined

# %%
#df.dropna(thresh = (len(df) * .8), axis = 0)
 
    # this kills the kernel
    
    
th = len(df) * 0.84
    
#df.dropna(th)

# %%
th

# %%
thresh

# %%
df.dropna(thresh= 27)

# %% [markdown]
# ### 4 or some num : Mall customers

# %%
# Mall customers

mall_query = '''
            SELECT * 
            FROM customers
            '''

# %%
mall_url = sql_connexion('mall_customers')

# %%
mall_df = pd.read_sql(mall_query, mall_url)

# %%
mall_df.head(2)

# %%
# making histograms with the dataframe

col = mall_df.columns.to_list()

for col in mall_df:
    plt.hist(mall_df[col])
    print(f'{col} distro')
    plt.show()

# %% [markdown]
#     1. Acquire data from the customers table in the mall_customers database.
#     2. Summarize the data (include distributions and descriptive statistics).
#     3. Detect outliers using IQR.
#     4. Split data into train, validate, and test.
#     5. Encode categorical columns using a one hot encoder (pd.get_dummies).
#     6. Handles missing values.
#     7. Scaling

# %%
mall_df['age'].quantile([0.25, 0.75])

# %%
q1, q3 = np.percentile(mall_df['age'], [25, 75])
q1, q3

# %%
def outlier_bound_calc(df, variable):
    
    q1, q3 = np.percentile(df[variable], [25, 75])
    
    iqr_val = q3 - q1
    
    lower_bound = q1 - (1.5 * iqr_val)

    upper_bound = q3 + (1.5 - iqr_val)
    
    return print(f'For {variable}, the lower bound is {lower_bound}, and the upper bound is {upper_bound}.')

# %%
# reutrning the above function with a dataframe

age_outliers = outlier_bound_calc(mall_df, 'age')

# %%
# isolating numeric & integers ; getting rid of objects
num_df = mall_df.select_dtypes(exclude = object)
num_df.info()

# %%
# finding the discretes / keeping only the objects

inc_obj = mall_df.select_dtypes(include = object)
inc_obj.info()

# %%
# fucntion

cols = num_df.columns.to_list()

for col in cols:
    outlier_bound_calc(num_df, [col])

# %%
# train, test, split

prepare.my_train_test_split(mall_df, 'spending_score')

# %%
train, validate, test

# %%
X_train.head()

# %%
# make dumies

dumdf = pd.get_dummies(train)
dumdf

# %%
# function to create dummies for a generic df

def encoding(df, cols, drop_first = True):
    
    for col in cols:
        dummies = pd.get_dummies(df[f'{col}'], drop_first = drop_first)
        df = pd.concat([df, dummies], axis = 1)
    return df

# %%
train_encoded = encoding(train, inc_obj, drop_first = True)

# %%
# handle missing
mall_df.isna().sum()

# %%
# scalling of age & income

mms = MinMaxScaler()

train_encoded[['age', 'annual_income']] = mms.fit_transform(train_encoded[['age', 'annual_income']])........

# %% [markdown]
# ### pd.iterrows https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iterrows.html
